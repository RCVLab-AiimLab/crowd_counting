# %% [markdown]
# Change the directory to where your code and dataset is. Here in Crowdcounting, I have two folders, one for datasets and the other one for code.

# %%
# !python /content/drive/My\ Drive/Queens/Crowdcounting_CARLA/code/make_dataset.py
# Out:
# this is part b
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# generate density...
# ...

# %%
import json
import numpy as np
import copy
f = open('/content/drive/My Drive/Queens/Crowdcounting_CARLA/code/part_B_train.json',)
files = json.load(f)
files2 = copy.deepcopy(files)
for i,name in enumerate(files):
    if int(name.split('/')[-1].split('_')[-1].split('.')[0])>100:
        # print(i)
        # print(name)
        files2.remove(name)
with open('/content/drive/My Drive/Queens/Crowdcounting_CARLA/code/part_B_train.json', 'w') as f:
    json.dump(files2, f)

# %% [markdown]
# Reverse x and y axis

# %%
import scipy.io
import os
import copy
path = '/content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset'
in_path1 = os.listdir(path)
for path1 in in_path1:
    in_path2 = os.listdir(os.path.join(path,path1))
    for path2 in in_path2:
        file_names = os.listdir(os.path.join(path,path1,path2,'ground_truth_wrong'))
        for file_name in file_names:
            if file_name.endswith(".mat"):
                mat = scipy.io.loadmat(os.path.join(path,path1,path2,'ground_truth_wrong',file_name))
                mat2 = copy.deepcopy(mat)
            # print(mat2['image_info'][0][0][0][0][0][0][1])
                for i in range(len(mat['image_info'][0][0][0][0][0])):
                    mat2['image_info'][0][0][0][0][0][i][1] = mat['image_info'][0][0][0][0][0][i][0]
                    mat2['image_info'][0][0][0][0][0][i][0] = mat['image_info'][0][0][0][0][0][i][1]
                # print(len(mat['image_info'][0][0][0][0][0]))
                # print(mat['image_info'][0][0][0][0][0][4][0])
                if not os.path.exists(os.path.join(path,path1,path2,'ground_truth')):
                    os.makedirs(os.path.join(path,path1,path2,'ground_truth'))
                scipy.io.savemat(os.path.join(path,path1,path2,'ground_truth',file_name), mat2)
                print(os.path.join(path,path1,path2,'ground_truth',file_name))

            # print(mat{'__header__'})
            # for i in mat :
            #     print(i)
            #     print(mat[i])
# Out:
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_1.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_2.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_4.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_3.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_5.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_6.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_8.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_9.mat
# /content/drive/My Drive/Queens/Crowdcounting_CARLA/dataset/part_B_final/train_data/ground_truth/GT_IMG_7.mat
# ...

# %%
print(in_path)
# Out:
# ['part_B_final', 'part_A_final']

# %% [markdown]
# To install and use wandb
# to track gpu usage and many other things :D

# %%
# !pip install wandb
import wandb
wandb.init()
# Out:
# ...
#      |████████████████████████████████| 1.8MB 8.5MB/s
# ...
#      |████████████████████████████████| 133kB 40.5MB/s
# ...
#      |████████████████████████████████| 174kB 37.1MB/s
# ...
#      |████████████████████████████████| 102kB 11.1MB/s
# ...
#      |████████████████████████████████| 71kB 8.4MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp37-none-any.whl size=8807 sha256=9ed09adf2ad0786f0baf201342457cdad58bf3dcb20b2f82e445214133187c71
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp37-none-any.whl size=6502 sha256=63ba8636cd1d75de48e55838c3f40bb4bb6b9f443aabfe9c40669abca302e104
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# Successfully built pathtools subprocess32
# ...
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %% [markdown]
# The state dict that is being saved as the checkpoint, contains the GPU (of that runtime) and total time (of all the runtimes).
# The GPU model and runtime is being logged in the gpu summarywriter as well.
# Logs are saved in:
# path>runs>logs

# %%
# !python /content/drive/My\ Drive/Queens/capsnet_crowd/code/train.py
# Out:
# CapsuleNetwork(
#   (l1): CapsuleConvLayer(
#     (conv_size): Conv2d(512, 512, kernel_size=(9, 9), stride=(2, 2))
#     (up): Upsample(size=(33, 24), mode=bilinear)
#     (conv0): Conv2d(512, 256, kernel_size=(9, 9), stride=(1, 1))
#     (relu): ReLU(inplace=True)
#   )
#   (l2): CapsuleLayer(
#     (unit_0): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_1): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_2): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_3): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_4): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_5): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_6): ConvUnit(
# ...

# %%
# !python /content/drive/My\ Drive/Queens/capsnet_crowd/code/train.py
# Out:
# CapsuleNetwork(
#   (l1): CapsuleConvLayer(
#     (conv_size): Conv2d(512, 512, kernel_size=(9, 9), stride=(2, 2))
#     (up): Upsample(size=(33, 24), mode=bilinear)
#     (conv0): Conv2d(512, 256, kernel_size=(9, 9), stride=(1, 1))
#     (relu): ReLU(inplace=True)
#   )
#   (l2): CapsuleLayer(
#     (unit_0): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_1): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_2): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_3): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_4): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_5): ConvUnit(
#       (conv0): Conv2d(256, 32, kernel_size=(9, 9), stride=(2, 2))
#     )
#     (unit_6): ConvUnit(
# ...

# %%
# !python /content/drive/My\ Drive/Queens/capsnet_crowd/code/train.py
# Out:
# /content
# path is /content/drive/My Drive/Queens/capsnet_crowd/code
# 2021-07-02 03:39:29.656474: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 32
# 512
# 1
# 32
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# => no checkpoint found at '/content/drive/My Drive/Queens/capsnet_crowd/code/runs/weights/checkpoint.pth.tar'
# epoch 0, processed 0 samples, lr 0.0000001000
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# ...

# %%
|!nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
import torch 
print(torch.__version__)
# Out:
# 1.9.0+cu102

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-8cd7b3cd-c337-cb7f-3fd6-e023f46731c7)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri May 14 21:48:09 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import sys
import os

import warnings

import torch
import torch.nn as nn
from torch.autograd import Variable
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
from skimage.transform import resize, downscale_local_mean

import numpy as np
import argparse
import json
import cv2
import time
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

class CSRNet(nn.Module):
    def __init__(self, load_weights=False):
        super(CSRNet, self).__init__()
        self.seen = 0
        self.frontend_feat = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512]
        self.conv_att_feat = ['A', 512]
        self.comp_feat = [32,1]
        self.frontend = make_layers(self.frontend_feat)
        self.conv_att = make_layers_conv_att(self.conv_att_feat,in_channels = 512)
        # self.caps = CapsNet(3)
        self.comp_mod = make_layers_comp(self.comp_feat)
        # self.caps_att = make_layers_caps_att()
        self.output_layer = nn.Conv2d(64, 1, kernel_size=1)
        if not load_weights:
            mod = models.vgg16(pretrained = True)
            self._initialize_weights()
            for i in range(len(self.frontend.state_dict().items())):
                list(self.frontend.state_dict().items())[i][1].data[:] = list(mod.state_dict().items())[i][1].data[:]
    def forward(self,x):
        x = self.frontend(x)
        x_att = self.conv_att(x).unsqueeze(-1).unsqueeze(-1)
        x_att = x_att * x
        x_conv_att = x_att + x
        x_att = self.comp_mod(x_conv_att)
        return x
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, std=0.01)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            
                
def make_layers(cfg, in_channels = 3,batch_norm=False,dilation = False):
    if dilation:
        d_rate = 2
    else:
        d_rate = 1
    layers = []
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=d_rate,dilation = d_rate)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)                 

def make_layers_conv_att(cfg, in_channels = 3, batch_norm=False, dilation = False):
    layers = []
    for v in cfg:
        if v == 'A':
            layers += [nn.AvgPool2d(kernel_size=28), nn.Flatten()]
        else:
            layers += [nn.Linear(in_features = 512, out_features = v), nn.ReLU(inplace=True), nn.Linear(in_features = 512, out_features = v), nn.Tanh()]
            in_channels = v
    return nn.Sequential(*layers)  

def make_layers_comp(cfg, in_channels = 512,batch_norm=True,dilation = False):
    layers = []
    for v in cfg:
        print(v)
        print(in_channels)
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv1 = nn.Conv2d(in_channels, v, kernel_size=1)
            # conv2 = nn.Conv2d(32, v, kernel_size=1)
            layers += [conv1, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)  

def main():
    i = 0
    while True:
        model = CSRNet()
        x = torch.rand(1,3,224,224)
        x = model(x)
        y = torch.rand_like(x)
        loss = nn.MSELoss()
        l = loss(x,y)
        
        optimizer = torch.optim.SGD(model.parameters(), 0.0001, momentum=0.9, weight_decay=0.1)
    # x = torch.rand_like
        optimizer.zero_grad()
        l.backward()
        optimizer.step()   
        print(i)
        i = i+1
    
if __name__ == '__main__':
    main()
# Out:
# 32
# 512
# 1
# 32
# 0
# 32
# 512
# 1
# 32
# 1
# 32
# 512
# 1
# 32
# 2
# 32
# 512
# 1
# 32
# 3
# 32
# 512
# 1
# 32
# 4
# 32
# 512
# 1
# 32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-6c480e91ad1d> in <module>()
#     117
#     118 if __name__ == '__main__':
# --> 119     main()
#
# <ipython-input-53-6c480e91ad1d> in main()
#     103         model = CSRNet()
#     104         x = torch.rand(1,3,224,224)
# --> 105         x = model(x)
#     106         y = torch.rand_like(x)
#     107         loss = nn.MSELoss()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# ...

# %%
x = torch.rand(224,224,3)
print(x.shape)
# Out:
# torch.Size([224, 224, 3])

# %%
import torch.nn as nn
import torch
from torchvision import models
# from caps import *


class CSRNet(nn.Module):
    def __init__(self, load_weights=False):
        super(CSRNet, self).__init__()
        self.seen = 0
        self.frontend_feat = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512]
        self.conv_att_feat = ['A', 512]
        self.comp_feat = [32,1]
        self.frontend = make_layers(self.frontend_feat)
        self.conv_att = make_layers_conv_att(self.conv_att_feat,in_channels = 512)
        self.caps = CapsNet(3)
        self.comp_mod = make_layers_comp(self.comp_feat)
        # self.caps_att = make_layers_caps_att()
        self.output_layer = nn.Conv2d(64, 1, kernel_size=1)
        if not load_weights:
            mod = models.vgg16(pretrained = True)
            self._initialize_weights()
            for i in range(len(self.frontend.state_dict().items())):
                list(self.frontend.state_dict().items())[i][1].data[:] = list(mod.state_dict().items())[i][1].data[:]
    def forward(self,x):
        x = self.frontend(x)
        x_att = self.conv_att(x).unsqueeze(-1).unsqueeze(-1)
        x_att = x_att * x
        x_conv_att = x_att + x
        x_att = self.comp_mod(x_conv_att)
        print(x_att.shape)
        return x_att
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.normal_(m.weight, std=0.01)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            
                
def make_layers(cfg, in_channels = 3,batch_norm=False,dilation = False):
    if dilation:
        d_rate = 2
    else:
        d_rate = 1
    layers = []
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=d_rate,dilation = d_rate)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)                 

def make_layers_conv_att(cfg, in_channels = 3, batch_norm=False, dilation = False):
    layers = []
    for v in cfg:
        if v == 'A':
            layers += [nn.AvgPool2d(kernel_size=28), nn.Flatten()]
        else:
            layers += [nn.Linear(in_features = 512, out_features = v), nn.ReLU(inplace=True), nn.Linear(in_features = 512, out_features = v), nn.Tanh()]
            in_channels = v
    return nn.Sequential(*layers)  

def make_layers_comp(cfg, in_channels = 512,batch_norm=True,dilation = False):
    layers = []
    for v in cfg:
        print(v)
        print(in_channels)
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv1 = nn.Conv2d(in_channels, v, kernel_size=1)
            # conv2 = nn.Conv2d(32, v, kernel_size=1)
            layers += [conv1, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)
