# %%
# !python /content/drive/My\ Drive/Queens/Crowdcounting/code/val.py
# Out:
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_10.jpg
# (96, 128)
# 0 1185.5722656249998
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_1.jpg
# (96, 128)
# 1 262.6781921386719
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_103.jpg
# (96, 128)
# 2 606.4713745117188
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_101.jpg
# (96, 128)
# 3 400.6556396484375
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_102.jpg
# (96, 128)
# 4 668.5524291992188
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_100.jpg
# (96, 128)
# 5 584.0145874023438
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_107.jpg
# (96, 128)
# ...

# %%
#part B
# !python /content/drive/My\ Drive/Queens/Crowdcounting/code/val.py
# Out:
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_10.jpg
# (96, 128)
# 0 28.340911865234517
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_1.jpg
# (96, 128)
# 1 4.198991775512688
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_103.jpg
# (96, 128)
# 2 0.8786506652832244
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_101.jpg
# (96, 128)
# 3 2.6044425964355327
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_102.jpg
# (96, 128)
# 4 7.450672149658217
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_100.jpg
# (96, 128)
# 5 32.59710693359378
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_B_final/test_data/images/IMG_107.jpg
# (96, 128)
# ...

# %%
#part A
# !python /content/drive/My\ Drive/Queens/Crowdcounting/code/val.py
# Out:
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/test_data/images/IMG_10.jpg
# (96, 128)
# 0 42.62857
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/test_data/images/IMG_110.jpg
# (85, 128)
# 1 196.64313
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/test_data/images/IMG_109.jpg
# (85, 128)
# 2 13.860809
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/test_data/images/IMG_1.jpg
# (88, 128)
# 3 115.613815
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/test_data/images/IMG_100.jpg
# (51, 112)
# 4 2.532196
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/test_data/images/IMG_107.jpg
# (57, 86)
# 5 83.78705
# /content/drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/test_data/images/IMG_106.jpg
# (59, 125)
# 6 82.705444
# ...
