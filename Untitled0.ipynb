# %%
# %cd drive/My Drive/Queens/Crowdcounting
# Out:
# /content/drive/My Drive/Queens/Crowdcounting

# %%
cd content
# Out:
# /content

# %%
cd/
# Out:
# /

# %%
# %ls
# Out:
# code/  dataset/

# %%
# !python code/make_dataset.py
# Out:
# ['dataset/ShanghaiTech/part_A_final/train_data/images', 'dataset/ShanghaiTech/part_A_final/test_data/images']
# ...

# %%
# !python code/make_dataset.py
# Out:
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_1.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_10.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_100.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_104.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_102.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_105.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_101.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_103.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_109.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_107.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_108.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_106.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_11.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_111.jpg
# dataset/ShanghaiTech/part_B_final/train_data/images/IMG_112.jpg
# ...

# %%
# !python code/train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# ****************************************************************************************************
# dataset/ShanghaiTech/part_A_final/train_data/ground_truth/IMG_160.h5
# (540, 1024)
# (67, 128)
# <PIL.Image.Image image mode=RGB size=1024x540 at 0x7FB7A2BD25D0>
# ****************************************************************************************************
# dataset/ShanghaiTech/part_A_final/train_data/ground_truth/IMG_260.h5
# (681, 1024)
# (85, 128)
# <PIL.Image.Image image mode=RGB size=1024x681 at 0x7FB7A2BD2710>
# ****************************************************************************************************
# dataset/ShanghaiTech/part_A_final/train_data/ground_truth/IMG_218.h5
# (411, 443)
# (51, 55)
# <PIL.Image.Image image mode=RGB size=443x411 at 0x7FB7A2BD2950>
# ****************************************************************************************************
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
import torch 
print(torch.__version__)
# Out:
# 1.8.1+cu101

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri May 14 21:48:09 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
print(torch.version)
print(torch.cuda.is_available())
# Out:
# <module 'torch.version' from '/usr/local/lib/python3.7/dist-packages/torch/version.py'>
# True

# %%
import os
os.path.exists('drive/My Drive/Queens/Crowdcounting/dataset/ShanghaiTech/part_A_final/train_data/images/IMG_281.jpg')
# Out:
# True

# %%
ls
# Out:
# code/  dataset/

# %%
cd content
# Out:
# /content
